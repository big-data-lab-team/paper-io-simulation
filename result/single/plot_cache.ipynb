# %% [markdown]
# This source code generate plots of file in cache with the log recorded from real execution and WRENCH simulator.
# The log files are stored in `fincore` directory.
# Figures are generated and saved in `figure` directory

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plot_cache

# %%
# Real execution, saved as 'fincore_real.svg'
plot_cache.plot_cache("fincore/real.csv", "real")

# %%
# Real execution, saved as 'fincore_wrench.svg'
plot_cache.plot_cache("fincore/sim.csv", "wrench")
