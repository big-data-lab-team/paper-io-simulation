# %% [markdown]
# Generate figure comparing memory profiling results of 2 input file sizes.
# The figure is generated and saved as `figures/single_memprof.svg`.

# %%
import plot_memprof

# %%
inputs=[20,100] #input in GB
makespan=[200, 1300] #makespan in second (x_max)
plot_memprof.compare_plot(inputs, makespan)
